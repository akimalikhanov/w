# %%
import numpy as np
import matplotlib.pyplot as plt

rand_img=np.random.randint(0, 256, (64, 64))
plt.figure(figsize=(5,5))
plt.imshow(rand_img, cmap='gray')
plt.axis('off');

# %%
import os
import pandas as pd
from PIL import Image
from sklearn import ensemble, metrics, model_selection
from tqdm import tqdm


# def create_dataset(train_df, img_dir):
#     images, targets=[], []
#     for i, row in tqdm(train_df.itterrows(), total=len(train_df), desc='processing images'):
